# %%
side_A = (input("Side A: "))
side_B = (input("Side B: "))
side_C = (input("Side C: "))
perimeter = float(side_A) + float(side_B) + float(side_C)
print("The perimeter of the triangle is: ", perimeter)
# Out:
# The perimeter of the triangle is:  150.78

# %%
my_age = int(21)
height = float(175.5)
Complex_Numbers = complex(3, 4)
Base = float(input("Enter the value of base: "))
height = float(input("Enter the value of height: "))
area = 0.5 * Base * height
print("The area of the triangle is: ", area)
# Out:
# The area of the triangle is:  100.0

# %%
# getting length and width of a rectangle and calculating it's area and perimeter
Length = int(input("Enter Length : "))
Width = int(input("Enter width: "))
Area = Length* Width
print(f"The area of the triangle is: {Area}")
preimeter = 2 * (Length + Width)
print(f"The preimeter of the traingle is: {preimeter}")
# Out:
# The area of the triangle is: 3500
# The preimeter of the traingle is: 240

# %%
# getting radius of a circle and calculating the area and circumfrence
raduis = float(input("Enter the radius : "))
pi = 3.14
area = pi * raduis * raduis
print(area)
circumference = 2 * pi * raduis
print(circumference)
# Out:
# 81.67139999999999
# 32.028

# %%
# Calculating the slope
# equation y =2x - 2
# Slope(m)
m = 2
# y-intercept(b)
b = -2
# x-intercept(srt y = 0 =>0 2x -2)
x_intercept = 2 / 2
# y-intercept point
y_intercept = (0, b)
print("Slope: ", m)
print("y_intercept: ", y_intercept)
print("x_intercept: ", (x_intercept, 0))
# Out:
# Slope:  2
# y_intercept:  (0, -2)
# x_intercept:  (1.0, 0)

# %%
import math
# points
x1, y1 = 2,2
x2, y2 = 6, 10
# Slope
slope = (y2 - y1) / (x2 - x1)
# Eucildean Distance
distance = math.sqrt((x2 - x1)**2 + (y2-y1)**2)
print("slope: ",slope)
print("Distance: ",distance)
# Out:
# slope:  2.0
# Distance:  8.94427190999916

# %%
import math
m_equation = 2
b = -2
# intercepts
y_intercept = (0 , b)
x_intercept = (-b / m_equation, 0 )
x1, y1 = 2,2
x2, y2 = 6,10
# slope from points
m_points = (y2 - y1) / (x2 - x1)
# calculating the distance betweem points
distance = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
# output
print("from Equation y=2x-2")
print("Slope: ", m_equation)
print("y-intercept: ", y_intercept)
print("x-intercept: ", x_intercept)

print("\nfrom points (2,2) and (6,10)")
print("Slope :", m_points)
print(" Distance: ", distance )
# Out:
# from Equation y=2x-2
# Slope:  2
# y-intercept:  (0, -2)
# x-intercept:  (1.0, 0)
#
# from points (2,2) and (6,10)
# Slope : 2.0
#  Distance:  8.94427190999916

# %%
# calculating the valu of Y
for x in range(-5, 2):
   y = x**2 + 6*x+ 9
   print("X= ",x ,"y= ",y)
# Out:
# X=  -5 y=  4
# X=  -4 y=  1
# X=  -3 y=  0
# X=  -2 y=  1
# X=  -1 y=  4
# X=  0 y=  9
# X=  1 y=  16

# %%
# find the lenghth of pyhton and dragon then making falsy comparison
word_1 = str("python")
word_2 = str( "dragon")
print (len(word_1))
print (len(word_2))
if  len(word_1) == 9:
    print(f"The word {word_1} is another rather ta pyhton")
else:
    print(f"The word {word_1} is Python")

if "on" in word_1 and "on" in word_2:
    print(f"There is on in both {word_1} and {word_2}")
else:
    print(f"There is no on in both {word_1} and {word_2}")
# Out:
# 6
# 6
# The word python is Python
# There is on in both python and dragon

# %%
# using "in" operator to check if jargon exsists in the sentence
word = str("i hope this course is not full of jargon.")
if "jargon" in word:
    print("The word jargon exsist in the sentence")
else:
    print("The word jargon does not exsist in the sentence")
# Out:
# The word jargon exsist in the sentence

# %%
# there is no on in pyhton and dragon
if "on" not  in word_1 and "on" not  in word_2:
    print(f"There is on in both {word_1} and {word_2}")
else:
    print(f"There is no on in both {word_1} and {word_2}")
# Out:
# There is no on in both python and dragon

# %%
# finding the length of pyhton and converting it to float and then to string
Text = "python"
print (len(Text))
print(str(Text))
Text = float(Text)
print(converted_to_float )
# Trrying to convert the python word to float will result to value error
# Out:
# 6
# pyhton
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 5
#       3 print (len(Text))
#       4 print(str(Text))
# ----> 5 Text = float(Text)
#       6 print(converted_to_float )
#
# ValueError: could not convert string to float: 'pyhton'

# %%
# checking if a number is Even or not
num = int(input("Enter a number: "))
if num % 2 == 0:
    print(f"The number {num} is Even")
else:
    print(f"The number {num} is not a even number")
# Out:
# The number 8 is Even

# %%
# checking floor division of 7 by 3 is equal to the int converted value of 2.7
floor_division = 7 // 3
print(float(floor_division))
print(int(floor_division))
# the floor division of 7 by 3 is not equal to the int converted value
# Out:
# 2.0
# 2

# %%
# checking if type '10' is equal to 10
num_1 = type('10')
num_2 = type(10)
if num_1 == num_2:
    print(f"The number { num_1} is equal to { num2}")
else:
    print(f"The number { num_1} is not equal to { num_2}")
# Out:
# The number <class 'str'> is not equal to <class 'int'>

# %%
# checking if int 9.8 is equal to 10
num_1 = 9.8
num_2 = 10
if num_1 == num_2:
    print(f"The Number {num_1} is equal to {num_2}")
else:
    print(f"The Number {num_1} is not equal to {num_2}")
# Out:
# The Number 9.8 is not equal to 10

# %%
# Calculating wekkly earning per week
hours = int(input("Enter Hours: "))
rate = int(input("Enter rate per hour: "))
weekly_earning = hours * rate
print(f"Your weekly earning is {weekly_earning}")
# Out:
# Your weekly earning is 1120

# %%
# Calculating how many second a peron gets 
years_Lived = int(input("Enter number of years you have lived: "))
Seconds = years_Lived * 365 * 24 * 60 * 60 
print(f"You have lived for {Seconds} Seconds")
# Out:
# You have lived for 3153600000 Seconds

# %%
print("1 1 1 1 1")
print("2 1 2 4 8")
print("3 1 3 9 27")
print("4 1 4 16 64")
print("5 1 5 25 125")
# Out:
# 1 1 1 1 1
# 2 1 2 4 8
# 3 1 3 9 27
# 4 1 4 16 64
# 5 1 5 25 125
